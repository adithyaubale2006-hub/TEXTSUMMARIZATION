# %% [markdown]
# # Text Summarization using PEGASUS
#
# This notebook contains the implementation and steps to fine-tune PEGASUS on the SAMSum dataset for abstractive dialogue summarization.

# %% [markdown]
# The full original notebook is also available at: https://github.com/adithyaubale2006-hub/HF_MULTI_MODEL/blob/main/TEXTSUMMARIZATION.ipynb
